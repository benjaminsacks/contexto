# %%
import sys
sys.path.append('..')

from src.data import make_dataset
# from src.simulations import run_simulations
from tqdm import tqdm

import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

import numpy as np
import pandas as pd

dim = 300
path_to_glove_pkl = (f"..\\data\\interim\\filtered_glove_{dim}d.pkl")

# %%
glove_df = pd.read_pickle(path_to_glove_pkl)
glove_df.head()
# Out:
#                   0         1         2         3         4         5    \
# investigate  0.140250  0.331350 -0.229910 -0.276540 -0.317240 -0.356950
# songwriter   0.053913 -0.040641 -0.086161  0.514280 -0.198130 -0.284970
# fiddle       0.008995  0.363350 -0.430620  0.172860 -0.227190 -0.233220
# fetal       -0.043492  0.368820 -0.855620 -0.013381 -0.911220  0.011425
# projection  -0.226480  0.322430 -0.541550 -0.344550 -0.079646  0.471120
#
#                   6         7         8        9    ...       290       291  \
# investigate  0.005847  0.051720  0.128770 -1.58300  ... -0.259580 -0.287750
# songwriter  -0.211120 -0.666030 -0.184480  0.76593  ...  0.570060 -0.101800
# fiddle      -0.146230  0.012655 -0.350340  0.94476  ...  0.597640  0.415760
# fetal       -0.070843 -0.426720  0.002572 -0.90318  ... -0.710880 -0.080809
# projection  -0.301820 -0.169040 -0.427430 -1.11810  ... -0.009833  0.261730
#
#                  292       293       294      295       296       297  \
# ...

# %%
word_magnitudes = glove_df.apply(np.linalg.norm, axis=1)
word_magnitudes.head()
# Out:
# investigate    6.120303
# songwriter     6.570812
# fiddle         5.918100
# fetal          7.776340
# projection     6.741690
# dtype: float32

# %%
word_magnitudes.sort_values().reset_index().to_csv(f"..\\data\\interim\\word_magnitudes_{dim}d.csv")

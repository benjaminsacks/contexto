# %%
import sys
sys.path.append('..')

from src.data import make_dataset
# from src.simulations import run_simulations
from tqdm import tqdm

import nltk
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

import numpy as np
import pandas as pd

path_to_glove_pkl = ("..\\data\\interim\\filtered_embeddings.pkl")

# %%
glove_df = pd.read_pickle(path_to_glove_pkl)
glove_df.head()
# Out:
#                  0         1         2        3         4         5    \
# reflect    -0.170670 -0.088720  0.017157  0.18242 -0.185590  0.234130
# enrollment -0.465090 -0.219590  0.358260  0.38522 -0.027810  0.308110
# tues        0.460910 -0.626870  0.040877  0.29463  0.105790  0.872230
# setting     0.017493  0.068254  0.289930  0.29395  0.086911 -0.064448
# nsw        -0.330850  0.131060  0.036245  0.20087 -0.255630  0.329060
#
#                 6         7        8         9    ...       290       291  \
# reflect    -0.13874  0.204430  0.22987 -1.682100  ...  0.341500  0.154960
# enrollment  0.39638 -0.128040 -0.21867 -0.301770  ... -0.024566 -0.469630
# tues        0.43041 -0.528840 -0.23462  0.998680  ...  0.015061 -0.131510
# setting     0.31851 -0.083044 -0.15941 -1.185900  ... -0.146550  0.015577
# nsw         0.34133 -0.028132 -0.24420  0.088733  ...  0.311240  0.118480
#
#                 292       293      294       295       296       297  \
# reflect     0.22177 -0.222390  0.43489 -0.175950 -0.325620  0.162590
# enrollment  0.11406  0.393970 -0.16266 -0.042335 -0.186100 -0.634310
# tues       -0.77552  0.011748 -0.16520  0.189930 -0.098721  0.350550
# setting    -0.55677  0.018016  0.25821  0.886690 -0.179130  0.032596
# nsw         0.22459 -0.485620  0.60333  0.189350 -0.428370  0.003639
#
#                  298       299
# reflect     0.138970 -0.361910
# enrollment  0.078559 -0.031963
# tues        0.699070  0.078969
# setting    -0.156790  0.482940
# nsw         0.461360 -0.045986
#
# [5 rows x 300 columns]

# %%
word_magnitudes = glove_df.apply(np.linalg.norm, axis=1)
word_magnitudes.head()
# Out:
# reflect       5.536983
# enrollment    7.220841
# tues          7.157743
# setting       5.159592
# nsw           6.698988
# dtype: float32

# %%
word_magnitudes.sort_values().reset_index().to_csv("..\\data\\interim\\word_magnitudes.csv")
